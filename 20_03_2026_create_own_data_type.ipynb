# %% [markdown]
# <a href="https://colab.research.google.com/github/007arjungangwar/Programming-in-Python-Section1/blob/main/20_03_2026_create_own_data_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3/7
# Out:
# 0.42857142857142855

# %%
l1=list()
print(type(l1))
# Out:
# <class 'list'>

# %%
class Fraction:
    def __init__(self,n,d):
        self.num=n
        self.den=d

    # def __str__(self):
    #     return "{}/{}".format(self.num,self.den)

    def __str__(self):
        return f"{self.num}/{self.den}"

    def __add__(self,other):
        temp_num=self.num*other.den+other.num*self.den
        tem_den=self.den*other.den
        return "{}/{}".format(temp_num,tem_den)

    def __sub__(self,other):
        temp_num=self.num*other.den-other.num*self.den
        tem_den=self.den*other.den
        return "{}/{}".format(temp_num,tem_den)

# %%
f1=Fraction(2,3)
f2=Fraction(2,7)
print(f1)
print(f2)
# Out:
# 2/3
# 2/7

# %%
print(f1.den,f1.num)
print(f2.den,f2.num)
# Out:
# 3 2
# 7 2

# %%
print(f1+f2)
# Out:
# 20/21

# %%
print(f1-f2)
# Out:
# 8/21

# %%
print(f1-f2)
# Out:
# 8/21

# %%
class Line:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
    def __str__(self):
        return f"{self.a}x+{self.b}y+{self.c}"

# %%
l1=Line(1,1,2)
print(l1)
# Out:
# 1x+1y+2

# %%
class Point:
    def __init__(self,x,y):
        self.x_co=x
        self.y_co=y
    def __str__(self):
        return f"<{self.x_co},{self.y_co}>"

    def __add__(self,other):
        temp_x=self.x_co+other.x_co
        temp_y=self.y_co+other.y_co
        return f"<{temp_x},{temp_y}>"

    def equlidiean_distance(self,other):
        return f"{((((self.x_co-other.x_co)**2)+((self.y_co-other.y_co)**2))**0.5):.2f}"

# %%
print(f"{2.2555646:.2f}")
print(round(2.2555646,2))
# Out:
# 2.26
# 2.26

# %%
p1=Point(1,2)
p2=Point(3,4)
print(p1)
print(p2)

print(p1+p2)
# Out:
# <1,2>
# <3,4>
# <4,6>

# %%
p1.equlidiean_distance(p2)
# Out:
# '2.83'

# %%
class Point:
    def __init__(self,x,y):
        self.x_co=x
        self.y_co=y
    def __str__(self):
        return f"<{self.x_co},{self.y_co}>"

    def __add__(self,other):
        temp_x=self.x_co+other.x_co
        temp_y=self.y_co+other.y_co
        return f"<{temp_x},{temp_y}>"

    def equlidiean_distance(self,other):
        # return f"{((((self.x_co-other.x_co)**2)+((self.y_co-other.y_co)**2))**0.5):.2f}"
        return round(((((self.x_co-other.x_co)**2)+((self.y_co-other.y_co)**2))**0.5),2)

class Line:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
    def __str__(self):
        return f"{self.a}x+{self.b}y+{self.c}=0"

    def point_lie_on_line(self,other):
        # ex_value={self.a}*{other.x_co}+{self.b}*{other.y_co}+{self.c} # {} creates a set, not a number.
        ex_value = self.a * other.x_co + self.b * other.y_co + self.c
        if ex_value==0:
            return "point lies on a line"
        else:
            return  "Point does`t lies on a line"

# %%
p1=Point(1,2)
p2=Point(3,4)
print(p1)
print(p2)
print(p1+p2)
print(p1.equlidiean_distance(p2))
# Out:
# <1,2>
# <3,4>
# <4,6>
# 2.83

# %%
l1=Line(1,1,-2)
print(l1)
# Out:
# 1x+1y+-2=0

# %%
p1=Point(1,1)
p2=Point(2,3)
print(l1.point_lie_on_line(p1))
print(l1.point_lie_on_line(p2))
# Out:
# point lies on a line
# Point does`t lies on a line

# %%
l2=Line(2,4,-16)
print(l2)
print(l2.point_lie_on_line(p1))
print(l2.point_lie_on_line(p2))
# Out:
# 2x+4y+-16=0
# Point does`t lies on a line
# point lies on a line
